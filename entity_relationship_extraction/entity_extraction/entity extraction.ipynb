# %% [markdown]
# # Entity Extraction

# %%
# import libraries
import pandas as pd
import spacy 
import ast
import re
from spacy.matcher import PhraseMatcher

# %% [markdown]
# ## Entity extraction functions

# %% [markdown]
# #### Extraction from structured column data

# %%
# definte extract_entities function
def extract_entities(text, label):
    entities = [(text, label)]
    return entities

# %% [markdown]
# #### Extraction from column with list of multiple data

# %%
# define extract_module_entities function
def extract_module_entities(module_list):
    module_list = ast.literal_eval(module_list)
    return [(module, 'MODULE') for module in module_list]

# %% [markdown]
# #### Extraction from chunk of unstructured text data

# %%
# load spacy model
nlp = spacy.load("en_core_web_md")

# load the jobs and skills data
jobs_and_skills = pd.read_csv("jobs_and_skillset_linkedin_final.csv")
jobs_and_skills.head()
# Out:
#                  Job Title                                             Skills
# 0     ['Academic Advisor']  ['Academic Advising', 'Higher Education', 'Stu...
# 1       ['Academic Tutor']  ['Tutoring', 'Teaching', 'Peer Tutoring', 'Mat...
# 2  ['Account Coordinator']  ['Account Management', 'Account Coordination',...
# 3     ['Account Director']  ['Account Management', 'Client Services', 'Cli...
# 4    ['Account Executive']  ['Software as a Service (SaaS)', 'Account Mana...

# %%
# get list of job titles and skills 
#job_titles = jobs_and_skills["Job Title"].to_list()
skills = jobs_and_skills["Skills"].unique().tolist()

# convert from string to list
#for i in range(len(job_titles)):
#    job_titles[i] = ast.literal_eval(job_titles[i])
#job_titles = [item for sublist in job_titles for item in sublist]

for i in range(len(skills)):
    skills[i] = ast.literal_eval(skills[i])

# create a list of unique skills
unique_skills = list(set([skill for sublist in skills for skill in sublist]))

#print(job_titles)
print(unique_skills)
print(len(unique_skills))
# Out:
# ['Therapeutic Modalities', 'Server Configuration', 'Legal Research', 'Electronics Repair', 'Student Recruiting', 'Theatrical Production', 'Enercalc', 'Creative Agency', 'Automotive Technology', 'Strategy', 'Grills', 'Clinical Nutrition', 'Classroom Management', 'Autodesk Inventor', 'Software Testing', 'Youth Leadership', 'Cocktails', 'Mechanical Product Design', 'Purchase Management', 'Appointment Scheduling', 'Stroke Rehabilitation', 'U.S. VA Loans', 'Team Management', 'Technical Leadership', 'Allen-Bradley', 'Excavation', 'Patient Scheduling', 'Housekeeping', 'Salesforce Sales Cloud', 'Content Design', 'Functional Behavior Assessments', 'Computer Repair', 'Mental Health Care', 'Mobile Testing', 'Legal Document Preparation', 'Series 6', 'Healthcare Management', 'Jenkins', 'CEOs', 'Electrical Wiring', 'Microdermabrasion', 'Event Photography', 'Technical Translation', 'Interior Design', 'Strategic Human Resource Planning', 'Patient Education', 'American Sign Language', 'Loan Origination', 'Laboratory Techniques', 'Laboratory Technicians', 'MIG Welding', 'IT Auditing', 'Corrective Maintenance', 'Spanish', 'Ultipro', 'Human Resources Information Systems (HRIS)', 'Encompass', 'Lawn Mowing', 'Insurance', 'Therapeutic Massage', 'AS9100', 'Food & Beverage', 'Credit Risk Management', 'Personal Care', 'Customer Experience', 'Copy Editing', 'Music Theory', 'Landscape Design', 'Venture Capital', 'Improvisation', 'Service Coordination', 'Farm Equipment', 'Suspension', 'Nutrition Education', 'SQL Server Analysis Services (SSAS)', 'Corporate Governance', 'Claim Investigation', 'SAP Concur', 'SQL Server Integration Services (SSIS)', 'Security Information and Event Management (SIEM)', 'Environmental Impact Assessment', 'Risk Assessment', 'Tailoring', 'Camtasia', 'Preaching', 'Greenhouse', 'Cisco Systems Products', 'Branding & Identity', 'Injury Rehabilitation', 'Hot Water', 'Creative Writing', 'Analytical Skills', 'Lean Six Sigma', 'Animal Care', 'Differentiated Instruction', 'X-ray', 'Inventory Planning', 'Cost Accounting', 'Firewalls', 'A&P', 'Digital Strategy', 'Off-Page SEO', 'Motion Graphics', 'Diesel Engine', 'Dermaplaning', 'Start-ups', 'Time Management', 'Process Engineering', 'Product Launch', 'Insurance Verification', 'Microsoft Servers', 'Caregiving', 'Singer-songwriter', 'Criminal Justice', 'Independent Film', 'Software Quality Assurance', 'Procore', 'C-arm', 'Equipment Operation', 'Pharmacy Technicians', 'Human Nutrition', 'Management Consulting', 'Commercial Photography', 'Soccer Coaching', 'Menu Development', 'Technology Evangelism', 'Instagram Marketing', 'Pet Care', 'Individual Counselling', 'Cisco Networking', 'Baking', 'Storytelling', 'Hair Coloring', 'CDL', 'Golf Club Repair', 'Partner Relationship Management', 'Tax Accounting', 'Molecular Cloning', 'Rehabilitation', 'Safety Culture', 'Holistic Life Coaching', 'Library Science', 'General Management', 'Hatha Yoga', 'Homeowners Insurance', 'Circulation', 'EMDR', 'MySQL', 'Autism Spectrum Disorders', 'Contracts Administrators', 'Bar', 'Corrections', 'and Safety (EHS)', 'Wardrobe', 'Special Events', 'Power Systems', 'Narrator', 'Landscape Construction', 'AWS Lambda', 'Inventory Control', 'WordPress', 'Visual Basic', 'HL7 Standards', 'Higher Education Recruitment', 'E-Learning', 'Sports Massage', 'Training Management', 'Copywriting', 'Compliance Monitoring', 'Consultative Selling', '401k Rollovers', 'Production Assistance', 'Communications Planning', 'Golf Management', 'Emergency Medical Services (EMS)', 'Steel Design', 'Kronos Time and Attendance', 'Spanish Teaching', 'Modern Dance', 'Newsletter Production', 'Real Estate', 'Resume Writing', 'Maintenance', 'Architecture', 'IT Recruitment', 'Electrical', 'Operational Excellence', 'Claims Management', 'Pharmacy Practice', 'Social Media Communications', 'Nursing Documentation', 'Chemical Peels', 'Performing Arts', 'Lease Administration', 'Food Service Operations', 'Audio Editing', 'Insurance Billing', 'LinkedIn Recruiter', 'Recept ...
# 2000

# %%
# clean unique_skills list

# remove bracketed abbreviations from skills and the space before it
unique_skills = [re.sub(r'\s\(.*\)', '', skill) for skill in unique_skills]

# remove 'Microsoft ' substring before skills
unique_skills = [re.sub(r'Microsoft\s', '', skill) for skill in unique_skills]

# %%
def extract_skill_entities(text):
    
    # process text with spaCy model to extract entities
    doc = nlp(text)

    # initialize a dictionary to store the entities
    #entities = {
    #    "Job Title": [],
    #    "Skill": []
    #}

    skills = []

    # extract job titles entities
    #for job_title in job_titles:
    #    if job_title.lower() in text.lower():
    #        entities["Job Title"].append(job_title)
    
    # extract skill entities
    for skill in unique_skills:
        # create a regex pattern with word boundaries around the job title
        pattern = r"\b" + re.escape(skill) + r"\b"
    
        # search for the job title in the text (case-insensitive)
        if re.search(pattern, text, re.IGNORECASE):
            skills.append((skill,'SKILL'))

    return skills

# %%
# test spacy_extract_entities function
sample_text = "John Doe is a Software Engineer at Google with experience in Python and cloud computing. Jane Smith is a Project Manager at Microsoft. She specializes in Project Management and Data Science. Both have worked extensively on Agile and DevOps projects."

# call the function
skill_entities = extract_skill_entities(sample_text)

# print the extracted entities
#for entity_type, entity_list in entities.items():
#    print(f"{entity_type}: {', '.join(entity_list) if entity_list else 'None'}")
print(skill_entities)
# Out:
# [('DevOps', 'SKILL'), ('Management', 'SKILL'), ('Cloud Computing', 'SKILL'), ('Python', 'SKILL'), ('Project', 'SKILL'), ('Data Science', 'SKILL'), ('Project Management', 'SKILL')]

# %% [markdown]
# ## 00 - Student Data

# %%
# load the student data
student_info = pd.read_csv('../../backend/data/00 - mock_student_data_final.csv')
# check the first few rows of the student_info dataframe
student_info.head()
# Out:
#       Student_Name Matric_Number       NRIC  Year  \
# 0      Tracy Lewis     A0216920B  XXXXX506Z     1
# 1    Andrew Holden     A0225069H  XXXXX799Z     3
# 2  Phillip Bullock     A0228204E  XXXXX194Z     1
# 3   Valerie Rivera     A0200778Y  XXXXX150Z     3
# 4      Robert Hall     A0222508M  XXXXX824Z     3
#
#                            Faculties                    Major  \
# 0                NUS Business School  Business Administration
# 1          YST Conservatory of Music                    Music
# 2  College of Design and Engineering   Electrical Engineering
# 3                          Computing       Business Analytics
# 4          YST Conservatory of Music                    Music
#
#               Second Major                                  Modules_Completed  \
# 0                      NaN  ['ACC1701B', 'DMB1202ACC', 'DMB1201MKT', 'MNO1...
# 1                      NaN  ['CFA1111A', 'MUA1190', 'MUA2109', 'MUA1172', ...
# 2                      NaN  ['ME1102', 'BN1111', 'PF1103', 'CN1101A', 'ID1...
# 3                      NaN  ['CS3236R', 'CS1010', 'CP3209', 'CS1010R', 'IS...
# 4  Business Administration  ['MUA1109', 'CFA1101A', 'MUA2255A', 'MUA1172',...
#
#                                               Grades
# 0  {'ACC1701B': 'B', 'DMB1202ACC': 'A', 'DMB1201M...
# 1  {'CFA1111A': 'F', 'MUA1190': 'A', 'MUA2109': '...
# 2  {'ME1102': 'F', 'BN1111': 'B-', 'PF1103': 'C+'...
# 3  {'CS3236R': 'A+', 'CS1010': 'A+', 'CP3209': 'A...
# 4  {'MUA1109': 'C+', 'CFA1101A': 'B-', 'MUA2255A'...

# %%
# extract entities from the student data
student_info['Student_entities'] = student_info['Student_Name'].apply(lambda x: extract_entities(x, 'STUDENT'))
student_info['Faculty_entities'] = student_info['Faculties'].apply(lambda x: extract_entities(x, 'FACULTY'))
student_info['Major_entities'] = student_info['Major'].apply(lambda x: extract_entities(x, 'MAJOR'))
student_info['Module_entities'] = student_info['Modules_Completed'].apply(lambda x: extract_module_entities(x))

# %%
# check the first few rows of the student_info dataframe
student_info.head()
# Out:
#       Student_Name Matric_Number       NRIC  Year  \
# 0      Tracy Lewis     A0216920B  XXXXX506Z     1
# 1    Andrew Holden     A0225069H  XXXXX799Z     3
# 2  Phillip Bullock     A0228204E  XXXXX194Z     1
# 3   Valerie Rivera     A0200778Y  XXXXX150Z     3
# 4      Robert Hall     A0222508M  XXXXX824Z     3
#
#                            Faculties                    Major  \
# 0                NUS Business School  Business Administration
# 1          YST Conservatory of Music                    Music
# 2  College of Design and Engineering   Electrical Engineering
# 3                          Computing       Business Analytics
# 4          YST Conservatory of Music                    Music
#
#               Second Major                                  Modules_Completed  \
# 0                      NaN  ['ACC1701B', 'DMB1202ACC', 'DMB1201MKT', 'MNO1...
# 1                      NaN  ['CFA1111A', 'MUA1190', 'MUA2109', 'MUA1172', ...
# 2                      NaN  ['ME1102', 'BN1111', 'PF1103', 'CN1101A', 'ID1...
# 3                      NaN  ['CS3236R', 'CS1010', 'CP3209', 'CS1010R', 'IS...
# 4  Business Administration  ['MUA1109', 'CFA1101A', 'MUA2255A', 'MUA1172',...
#
#                                               Grades  \
# 0  {'ACC1701B': 'B', 'DMB1202ACC': 'A', 'DMB1201M...
# 1  {'CFA1111A': 'F', 'MUA1190': 'A', 'MUA2109': '...
# 2  {'ME1102': 'F', 'BN1111': 'B-', 'PF1103': 'C+'...
# 3  {'CS3236R': 'A+', 'CS1010': 'A+', 'CP3209': 'A...
# 4  {'MUA1109': 'C+', 'CFA1101A': 'B-', 'MUA2255A'...
#
#                Student_entities  \
# 0      [(Tracy Lewis, STUDENT)]
# 1    [(Andrew Holden, STUDENT)]
# 2  [(Phillip Bullock, STUDENT)]
# 3   [(Valerie Rivera, STUDENT)]
# 4      [(Robert Hall, STUDENT)]
#
#                                  Faculty_entities  \
# 0                [(NUS Business School, FACULTY)]
# 1          [(YST Conservatory of Music, FACULTY)]
# 2  [(College of Design and Engineering, FACULTY)]
# 3                          [(Computing, FACULTY)]
# 4          [(YST Conservatory of Music, FACULTY)]
#
#                        Major_entities  \
# 0  [(Business Administration, MAJOR)]
# 1                    [(Music, MAJOR)]
# 2   [(Electrical Engineering, MAJOR)]
# 3       [(Business Analytics, MAJOR)]
# 4                    [(Music, MAJOR)]
#
#                                      Module_entities
# 0  [(ACC1701B, MODULE), (DMB1202ACC, MODULE), (DM...
# 1  [(CFA1111A, MODULE), (MUA1190, MODULE), (MUA21...
# 2  [(ME1102, MODULE), (BN1111, MODULE), (PF1103, ...
# 3  [(CS3236R, MODULE), (CS1010, MODULE), (CP3209,...
# 4  [(MUA1109, MODULE), (CFA1101A, MODULE), (MUA22...

# %% [markdown]
# ## 01 - Module Info

# %%
# load module info data
module_info = pd.read_csv('../../backend/data/01 - mock_module_info.csv')

# check first few rows of the module_info dataframe
module_info.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[22], line 2
#       1 # load module info data
# ----> 2 module_info = pd.read_csv('../backend/data/01 - mock_module_info.csv')
#       4 # check first few rows of the module_info dataframe
#       5 module_info.head()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../backend/data/01 - mock_module_info.csv'

# %%
# check type of columns in module_info
print(module_info.dtypes)

# change type of description to string
module_info['description'] = module_info['description'].astype(str)
# Out:
# moduleCode                  object
# title                       object
# description                 object
# moduleCredit               float64
# department                  object
# faculty                     object
# gradingBasisDescription     object
# prerequisite                object
# preclusion                  object
# attributes                  object
# corequisite                 object
# lectureHours                 int64
# tutorialHours               object
# labHours                     int64
# projectHours                object
# prepHours                    int64
# semester_01                  int64
# semester_02                  int64
# semester_03                  int64
# semester_04                  int64
# UE                           int64
# dtype: object

# %%
# extract entities from the module data
module_info['Module_entities'] = module_info['moduleCode'].apply(lambda x: extract_entities(x, 'MODULE'))
module_info['Department_entities'] = module_info['department'].apply(lambda x: extract_entities(x, 'DEPARTMENT'))
module_info['Faculty_entities'] = module_info['faculty'].apply(lambda x: extract_entities(x, 'FACULTY'))
module_info['Skill_entities'] = module_info['description'].apply(lambda x: extract_skill_entities(x))

# %%
# check first few rows of the module_info dataframe
module_info.head()
# Out:
#   moduleCode                                title  \
# 0    ABM5001            Leadership in Biomedicine
# 1    ABM5002  Advanced Biostatistics for Research
# 2    ABM5003   Biomedical Innovation & Enterprise
# 3    ABM5004                     Capstone Project
# 4    ABM5101                   Applied Immunology
#
#                                          description  moduleCredit  \
# 0  Leadership is fundamental to the success of in...           2.0
# 1  This course is served as a concept-based intro...           2.0
# 2  This course will furnish students with a thoro...           4.0
# 3  This course encompasses research projects rele...           8.0
# 4  Advanced immunological applications play impor...           4.0
#
#                    department                       faculty  \
# 0  NUS Medicine Dean's Office  Yong Loo Lin Sch of Medicine
# 1  NUS Medicine Dean's Office  Yong Loo Lin Sch of Medicine
# 2  NUS Medicine Dean's Office  Yong Loo Lin Sch of Medicine
# 3  NUS Medicine Dean's Office  Yong Loo Lin Sch of Medicine
# 4  NUS Medicine Dean's Office  Yong Loo Lin Sch of Medicine
#
#   gradingBasisDescription prerequisite preclusion attributes  ... prepHours  \
# 0                  Graded           []         []        NaN  ...         0
# 1                  Graded           []         []        NaN  ...         0
# 2                  Graded           []         []        NaN  ...         0
# 3                  Graded           []         []        NaN  ...         0
# 4                  Graded           []         []        NaN  ...         0
#
#    semester_01 semester_02  semester_03 semester_04  UE      Module_entities  \
# 0            0           1            0           0   0  [(ABM5001, MODULE)]
# 1            0           1            0           0   0  [(ABM5002, MODULE)]
# 2            1           0            0           0   0  [(ABM5003, MODULE)]
# 3            1           1            0           0   0  [(ABM5004, MODULE)]
# 4            1           0            0           0   0  [(ABM5101, MODULE)]
#
#                           Department_entities  \
# 0  [(NUS Medicine Dean's Office, DEPARTMENT)]
# 1  [(NUS Medicine Dean's Office, DEPARTMENT)]
# 2  [(NUS Medicine Dean's Office, DEPARTMENT)]
# 3  [(NUS Medicine Dean's Office, DEPARTMENT)]
# 4  [(NUS Medicine Dean's Office, DEPARTMENT)]
#
#                             Faculty_entities  \
# 0  [(Yong Loo Lin Sch of Medicine, FACULTY)]
# 1  [(Yong Loo Lin Sch of Medicine, FACULTY)]
# 2  [(Yong Loo Lin Sch of Medicine, FACULTY)]
# 3  [(Yong Loo Lin Sch of Medicine, FACULTY)]
# 4  [(Yong Loo Lin Sch of Medicine, FACULTY)]
#
#                                       Skill_entities
# 0                              [(Leadership, SKILL)]
# 1  [(Research, SKILL), (Extract, SKILL), (Healthc...
# 2  [(Research, SKILL), (Research and Development,...
# 3                                [(Research, SKILL)]
# 4  [(Research, SKILL), (Design, SKILL), (Health, ...
#
# [5 rows x 25 columns]

# %% [markdown]
# ## 02 - Department Info

# %%
# load department info data
department_info = pd.read_csv('../../backend/data/02 - mock_department_list.csv')

# check first few rows of the department_info dataframe
department_info.head()
# Out:
#   department_id                    department  \
# 0     NUSDP0001    NUS Medicine Dean's Office
# 1     NUSDP0002                  Architecture
# 2     NUSDP0003                    Accounting
# 3     NUSDP0004  Communications and New Media
# 4     NUSDP0005                       History
#
#                              faculty
# 0       Yong Loo Lin Sch of Medicine
# 1  College of Design and Engineering
# 2                NUS Business School
# 3            Arts and Social Science
# 4            Arts and Social Science

# %%
# extract entities from the department data
department_info['Department_entities'] = department_info['department'].apply(lambda x: extract_entities(x, 'DEPARTMENT'))
department_info['Faculty_entities'] = department_info['faculty'].apply(lambda x: extract_entities(x, 'FACULTY'))

# %%
# check first few rows of the department_info dataframe``
department_info.head()
# Out:
#   department_id                    department  \
# 0     NUSDP0001    NUS Medicine Dean's Office
# 1     NUSDP0002                  Architecture
# 2     NUSDP0003                    Accounting
# 3     NUSDP0004  Communications and New Media
# 4     NUSDP0005                       History
#
#                              faculty  \
# 0       Yong Loo Lin Sch of Medicine
# 1  College of Design and Engineering
# 2                NUS Business School
# 3            Arts and Social Science
# 4            Arts and Social Science
#
#                             Department_entities  \
# 0    [(NUS Medicine Dean's Office, DEPARTMENT)]
# 1                  [(Architecture, DEPARTMENT)]
# 2                    [(Accounting, DEPARTMENT)]
# 3  [(Communications and New Media, DEPARTMENT)]
# 4                       [(History, DEPARTMENT)]
#
#                                  Faculty_entities
# 0       [(Yong Loo Lin Sch of Medicine, FACULTY)]
# 1  [(College of Design and Engineering, FACULTY)]
# 2                [(NUS Business School, FACULTY)]
# 3            [(Arts and Social Science, FACULTY)]
# 4            [(Arts and Social Science, FACULTY)]

# %% [markdown]
# ## 03 - Staff Info

# %%
# load staff info data
staff_info = pd.read_csv('../../backend/data/03 - mock_staff_info.csv')

# check first few rows of the staff_info dataframe
staff_info.head()
# Out:
#   Employee ID           Employee Name       NRIC                   DOB  \
# 0  NUSPF12345  Marin Sergio Hernandez  XXXXX479A  1983-02-23T00:00:00Z
# 1  NUSPF12346         Kathryn Cordova  XXXXX815A  1985-09-02T00:00:00Z
# 2  NUSPF12347         Barbara Sanchez  XXXXX777A  1971-07-30T00:00:00Z
# 3  NUSPF12348             Bryce Lucas  XXXXX610A  1973-07-20T00:00:00Z
# 4  NUSPF12349          Judith Camacho  XXXXX629A  1991-11-16T00:00:00Z
#
#                     DOJ                           Department Modules Taught
# 0  2009-10-31T00:00:00Z  Electrical and Computer Engineering        CEG5003
# 1  2009-06-07T00:00:00Z  Civil and Environmental Engineering        ESE2102
# 2  2008-05-09T00:00:00Z          Centre for Language Studies      LAT4201HM
# 3  2002-01-17T00:00:00Z                    BIZ Dean's Office     DMB1203MNO
# 4  2000-02-13T00:00:00Z                            Economics       EC4401HM

# %%
# extract entities from the staff_info data
staff_info['Staff_entities'] = staff_info['Employee Name'].apply(lambda x: extract_entities(x, 'STAFF'))
staff_info['Department_entities'] = staff_info['Department'].apply(lambda x: extract_entities(x, 'DEPARTMENT'))
staff_info['Module_entities'] = staff_info['Modules Taught'].apply(lambda x: extract_entities(x, 'MODULE'))

# %%
# check first few rows of the staff_info dataframe
staff_info.head()
# Out:
#   Employee ID           Employee Name       NRIC                   DOB  \
# 0  NUSPF12345  Marin Sergio Hernandez  XXXXX479A  1983-02-23T00:00:00Z
# 1  NUSPF12346         Kathryn Cordova  XXXXX815A  1985-09-02T00:00:00Z
# 2  NUSPF12347         Barbara Sanchez  XXXXX777A  1971-07-30T00:00:00Z
# 3  NUSPF12348             Bryce Lucas  XXXXX610A  1973-07-20T00:00:00Z
# 4  NUSPF12349          Judith Camacho  XXXXX629A  1991-11-16T00:00:00Z
#
#                     DOJ                           Department Modules Taught  \
# 0  2009-10-31T00:00:00Z  Electrical and Computer Engineering        CEG5003
# 1  2009-06-07T00:00:00Z  Civil and Environmental Engineering        ESE2102
# 2  2008-05-09T00:00:00Z          Centre for Language Studies      LAT4201HM
# 3  2002-01-17T00:00:00Z                    BIZ Dean's Office     DMB1203MNO
# 4  2000-02-13T00:00:00Z                            Economics       EC4401HM
#
#                       Staff_entities  \
# 0  [(Marin Sergio Hernandez, STAFF)]
# 1         [(Kathryn Cordova, STAFF)]
# 2         [(Barbara Sanchez, STAFF)]
# 3             [(Bryce Lucas, STAFF)]
# 4          [(Judith Camacho, STAFF)]
#
#                                  Department_entities         Module_entities
# 0  [(Electrical and Computer Engineering, DEPARTM...     [(CEG5003, MODULE)]
# 1  [(Civil and Environmental Engineering, DEPARTM...     [(ESE2102, MODULE)]
# 2        [(Centre for Language Studies, DEPARTMENT)]   [(LAT4201HM, MODULE)]
# 3                  [(BIZ Dean's Office, DEPARTMENT)]  [(DMB1203MNO, MODULE)]
# 4                          [(Economics, DEPARTMENT)]    [(EC4401HM, MODULE)]

# %%
# write the data to new csv files
student_info.to_csv('student_info_final.csv', index=False)
module_info.to_csv('module_info_final.csv', index=False)
department_info.to_csv('department_info_final.csv', index=False)
staff_info.to_csv('staff_info_final.csv', index=False)
