# %%
# !npm init -y
# !npm install neovis.js
# Out:
# Wrote to c:\Users\xinyu\OneDrive - National University of Singapore\ARGHHH UNI\Y4\DSA3101 Data Science in Practice\Project Repository\DSA3101--DD\frontend\package.json:
#
# {
#   "name": "frontend",
#   "version": "0.1.0",
#   "private": true,
#   "dependencies": {
#     "@testing-library/jest-dom": "^5.17.0",
#     "@testing-library/react": "^13.4.0",
#     "@testing-library/user-event": "^13.5.0",
#     "axios": "^1.7.7",
#     "chart.js": "^4.4.4",
#     "md5": "^2.3.0",
#     "react": "^18.3.1",
#     "react-chartjs-2": "^5.2.0",
#     "react-dom": "^18.3.1",
#     "react-modal": "^3.16.1",
#     "react-router-dom": "^6.26.2",
#     "react-scripts": "5.0.1",
#     "web-vitals": "^2.1.4"
#   },
#   "scripts": {
#     "start": "react-scripts start",
#     "build": "react-scripts build",
#     "test": "react-scripts test",
#     "eject": "react-scripts eject"
#   },
#   "eslintConfig": {
#     "extends": [
#       "react-app",
#       "react-app/jest"
#     ]
#   },
# ...

# %%
const config = {
  container_id: "viz",
  server_url: "neo4j+s://<your-database-id>.databases.neo4j.io", // Replace with your actual Neo4j URL
  server_user: "neo4j", // Your username, usually 'neo4j'
  server_password: "your-password", // Replace with your actual password
  labels: {
    "Person": {
      "caption": "name",
      "size": "pagerank",
      "community": "community"
    }
  },
  relationships: {
    "KNOWS": {
      "caption": true,
      "thickness": "weight"
    }
  },
  arrows: true
};
